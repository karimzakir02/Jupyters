# %% [markdown]
# # Predicting Rent Prices for houses/apartments in the Brazilian Real Estate Market
# ## By: Karim Zakir
# In this notebook, I will analyze and build a model from start to finish for the [Brazilian Houses To Rent](https://www.kaggle.com/rubenssjr/brasilian-houses-to-rent) dataset found on Kaggle. I will visualize the data, prepare it for machine learning, and finally create different models in attempt to accurately predict a variable in the dataset. Let's start by importing the necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from scipy.spatial.distance import mahalanobis
from scipy.stats import chi2
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift
import warnings
warnings.filterwarnings("ignore")

# %%
houses = pd.read_csv("datasets/houses_to_rent_v2.csv")
houses.head()
# Out:
#            city  area  rooms  bathroom  parking spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# ...

# %%
houses.shape
# Out:
# (10692, 13)

# %% [markdown]
# As you can see, there are 10692 observations and 13 columns. Most of the columns are (or seem to be) numerical, while some like 'city', 'animal', and 'furniture' are categorical. We will make sure to encode these columns later.

# %% [markdown]
# ### Data Analysis and Visualization

# %% [markdown]
# The first main section of this notebook will be Data Analysis and Visualization. In this section, we will get to know the data, analyze and visualize it, and select the target variable for our machine learning model.
#
# We will begin by looking at the data distribution for each of the numerical columns and analyzing them.

# %%
# Getting the numerical columns
num_cols = houses.select_dtypes(include=np.number).columns.tolist()
num_cols
# Out:
# ['area',
#  'rooms',
#  'bathroom',
#  'parking spaces',
#  'hoa (R$)',
#  'rent amount (R$)',
#  'property tax (R$)',
#  'fire insurance (R$)',
#  'total (R$)']

# %% [markdown]
# Although most of the numerical columns are within the above list, it is missing the floor column, which, logically, should be numerical. Let's check the unique values for this column.

# %%
houses["floor"].unique()
# Out:
# array(['7', '20', '6', '2', '1', '-', '4', '3', '10', '11', '24', '9',
#        '8', '17', '18', '5', '13', '15', '16', '14', '26', '12', '21',
#        '19', '22', '27', '23', '35', '25', '46', '28', '29', '301', '51',
#        '32'], dtype=object)

# %% [markdown]
# As you can see, this column's data type is object, because it contains the string value '-'. It is possible that this value can represent missing data; however, my first instict was that this value represents single-storey houses or apartments on the ground floor. This is, indeed, the case, as [confirmed by the author](https://www.kaggle.com/rubenssjr/brasilian-houses-to-rent/discussion/161708) of the dataset on Kaggle. As such, we will convert the floor column into a numerical column and replace the '-' with 0.

# %%
houses["floor"] = houses["floor"].replace({"-": "0"}).astype(int)

# %%
num_cols = houses.select_dtypes(include=np.number).columns.tolist()
fig, axs = plt.subplots(2, 5, figsize=(20, 10))
fig.suptitle("Data Distribution of Numerical Columns")
for index, col in enumerate(num_cols):
    if index < 5:  
        sns.histplot(ax=axs[0][index], data=houses, x=col)
    else:
        sns.histplot(ax=axs[1][index-5], data=houses, x=col)
plt.show()

# %% [markdown]
# Based on the above plots, we can see that the distributions for the numeric columns are heavily skewed to the right, suggesting that there are more low to middle-class than high-class houses in the dataset.
#
# Some of the plots, such as the property tax or area plots, are not displayed as well as we would have hoped. This is because of the extreme values that occur at the end of the distributions, which are outliers. We will take a closer look at them in the later section, when we need to decide whether to remove those values or not. At the moment, we will set the limits to the plots in order to take a proper look at the majority of values.

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 8))
fig.suptitle("Data Distribution of Numerical Columns")
area_plot = sns.histplot(ax=axs[0], data=houses, x="area")
area_plot.set(xlim=(0, 1000))
hoa_plot = sns.histplot(ax=axs[1], data=houses, x="hoa (R$)")
hoa_plot.set(xlim=(0, 6000))
pt_plot = sns.histplot(ax=axs[2], data=houses, x="property tax (R$)")
pt_plot.set(xlim=(0, 2000))
total_plot = sns.histplot(ax=axs[3], data=houses, x="total (R$)")
total_plot.set(xlim=(0, 30000))
floor_plot = sns.histplot(ax=axs[4], data=houses, x="floor")
floor_plot.set(xlim=(0, 40))
plt.show()

# %% [markdown]
# Similarly to previous data distributions, the data distributions above are heavily skewed to the right, reinforcing the idea that this dataset is mostly foucsed on low to middle-class housing. As such, we will attempt to create separate models for the different house classes in order to attempt to get the best results for each housing class, as well as use a single model for all of the classes and compare the accuracies of the models.
#
# These data distributions can help us pick the target variable for our model. The first call would be to have the 'total' column be the target variable, since it is made up of the core rent amount and taxes/insurances; however the model would become unrealiable in my opinion, because of the inconsistencies present in the 'hoa' and the 'property tax' columns. For instance, the 'hoa' column represents the home owners association tax. As you can see within the plot above, a lot of the observations have home owners association tax equal to 0. It is not clear whether this indicates missing data or an exemption from the tax. This is also the case for the 'property tax' column. Additionally, as we saw previously, there are outliers in the hoa and the property tax columns, which cause the total column to also have outliers that we will have to deal with later. As such, it is best to use the rent amount column as the target variable, since it does not depend on inconsistent columns in the dataset or does not require background knowledge about the Brazilian taxation system. Additionally, another benefit to using the rent amount column is that the model will not be affected by the changes in the taxation system within Brazil, making our potential model more future-proof.
#
# Let's save our potential X and y dataframes and look at the categorical variables in the dataset. We are completely excluding columns like 'fire insurance', 'property tax', and 'total', because data from these columns would not be available to us when trying to determine 'rent amount' for a new apartment. Other columns will be kept, and we will check whether they will be good features for our model later.

# %%
potential_features = ["city", "area", "rooms", "bathroom", "parking spaces", "floor", "animal", "furniture"]
target = ["rent amount (R$)"]

X = houses[potential_features]
y = houses[target]

# %%
cat_cols = houses.select_dtypes(exclude=np.number).columns.tolist()

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 8))
fig.suptitle("Value Count for Each Categorical Column")
for index, col in enumerate(cat_cols):
    sns.countplot(ax=axs[index], data=houses, x=col)
plt.show()

# %% [markdown]
# From these plots, we can see that there are only two categories in both the 'animal' column and the 'furniture' column. This will make it quite easy to enocode the columns later on. However, this kind of binary indication can worsen the performance of our model with the 'furniture' column specifically, because the variable does not indicate how well the apartment is furnished.
#
# The dataset mostly contains houses/apartments located in Sao Paulo, which makes sense because Sao Paulo is the most popoulous city in Brazil. The fact that Sao Paulo is the most popoulous city can indicate that the 'city' column will most-likely affect the rent amount, due to the higher demand present in certain cities.
#
# Let's start preprocessing our data and selecting the features for our model.

# %% [markdown]
# ### Data Preprocessing and Feature Selection

# %% [markdown]
# Now, we will prepare the dataset for model training. This will be done in several stages:
# 1. Split the data into the training and testing datasets
# 2. Check for missing data within the dataset and decide how to deal with it
# 3. Identify outliers in the dataset and determine whether to keep them or remove them
# 4. Select the best features for the model

# %% [markdown]
# #### Splitting the Data

# %% [markdown]
# We will split the data in two datasets in order to first train the data and then use the remaining data to test our models. It is essential to ensure that the data split is the first step of data preprocessing in order to avoid data leakage when preparing the data later. I will use the standard 80-20 split, since this is widely used in the data science industry.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

# %% [markdown]
# #### Missing Data

# %% [markdown]
# Our second step in datapreprocessing is to find any missing data within the dataset and decide how to deal with it. I will approach this task by looking at the dataset as a whole and try to identify the observations which contain np.NaN. Afterwards, I will take a look at each column individually to ensure that there are no 'strange' values which could possibly indicate missing values.

# %%
X_train_missing = [col for col in X_train.columns if X_train[col].isnull().any()]
X_test_missing = [col for col in X_test.columns if X_test[col].isnull().any()]
y_train_missing = [col for col in y_train.columns if y_train[col].isnull().any()]
y_test_missing = [col for col in y_test.columns if y_test[col].isnull().any()]

# %%
print("Columns with missing values in X_train:", X_train_missing)
print("Columns with missing values in X_test:", X_test_missing)
print("Columns with missing values in y_train:", y_train_missing)
print("Columns with missing values in y_test:", y_test_missing)
# Out:
# Columns with missing values in X_train: []
# Columns with missing values in X_test: []
# Columns with missing values in y_train: []
# Columns with missing values in y_test: []

# %% [markdown]
# As you can see, no columns in any of the dataframes have any observations with np.NaN. This, however, does not necessarily confirm that there are no missing observations in the dataset, since they can be denoted by different values, which may stand out within the variable. So, let's take a look at each column individually and try to identify any missing values.
#
# As we saw previously, there are no 'strange' values in our categorical columns, since they have a limited amount of categories. Using this analysis, we can confirm that these columns have no missing values, so we will move on to the numerical columns.

# %% [markdown]
# For the 'area', 'rooms', and 'bathroom' variables, we are going to take a particular approach to detect missing values. The most obvious way to denote missing values within those variables would be to represent them using non-positive values, since zero or negative values make no sense within those columns. Thus, we will attempt to find any observations with non-positive values.

# %%
# Checking for potentially missing values in X_train
X_train_area = X_train["area"] <= 0
X_train_rooms = X_train["rooms"] <= 0
X_train_bathroom = X_train["bathroom"] <= 0
X_train[(X_train_area) | (X_train_rooms) | (X_train_bathroom)]
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture]
# Index: []

# %%
# Checking for potentially missing values in X_test 
X_test_area = X_test["area"] <= 0
X_test_rooms = X_test["rooms"] <= 0
X_test_bathroom = X_test["bathroom"] <= 0
X_test[(X_test_area) | (X_test_rooms) | (X_test_bathroom)]
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture]
# Index: []

# %% [markdown]
# As you can see above, no observation contains a non-positive value in the 'area', 'rooms', and 'bathroom' columns in both the training and the testing dataframes. This allows us to confirm that these columns do not have any missing values. Some may argue that extreme values we saw in the earlier historgrams may denote missing values; however, this is unlikely. Those values are probably outliers, which we will investigate in a later section of this notebook.
#
# Now, we should take a closer look at the 'parking spaces' column. First, we will filter for strictly negative values, since, it is plausble that certain houses or apartments can have no parking; however, we will still take a look at the observations, which contain zero in the 'parking spaces' variable to ensure that we do not skip any missing values.

# %%
X_train[X_train["parking spaces"] < 0]
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture]
# Index: []

# %%
X_test[X_test["parking spaces"] < 0]
# Out:
# Empty DataFrame
# Columns: [city, area, rooms, bathroom, parking spaces, floor, animal, furniture]
# Index: []

# %% [markdown]
# As you can see, there are no strictly negative values in the 'parking spaces' column in neither the training nor the testing dataset, so let's move on to the observations, which contain no parking spaces and create a statistical summary for those records.

# %%
X_train[X_train["parking spaces"] == 0].describe()
# Out:
#                area        rooms     bathroom  parking spaces        floor
# count   2156.000000  2156.000000  2156.000000          2156.0  2156.000000
# mean      78.349258     1.713358     1.352505             0.0     4.094620
# std      280.720335     0.926750     0.787989             0.0     4.715906
# min       11.000000     1.000000     1.000000             0.0     0.000000
# 25%       36.000000     1.000000     1.000000             0.0     1.000000
# 50%       52.000000     1.000000     1.000000             0.0     3.000000
# 75%       80.000000     2.000000     1.000000             0.0     6.000000
# max    12732.000000     8.000000     7.000000             0.0    32.000000

# %%
X_test[X_test["parking spaces"] == 0].describe()
# Out:
#              area       rooms    bathroom  parking spaces       floor
# count  527.000000  527.000000  527.000000           527.0  527.000000
# mean    81.586338    1.781784    1.472486             0.0    4.060721
# std     82.480990    0.949189    1.001283             0.0    4.824300
# min     15.000000    1.000000    1.000000             0.0    0.000000
# 25%     39.500000    1.000000    1.000000             0.0    1.000000
# 50%     56.000000    1.000000    1.000000             0.0    2.000000
# 75%     90.000000    2.000000    2.000000             0.0    6.000000
# max    700.000000    7.000000   10.000000             0.0   25.000000

# %% [markdown]
# 2156 observations in the training dataset have no parking spaces. Based on the mean value, as well as the median and the first and third quartile values, it seems plausible that such observations would contain no parking spaces, since they represent relatively small houses/apartments, which would not necessarily contain parking spaces. If we take a closer look at the maximum values, however, we can see that those values represent large houses/apartments, and it would not make sense for them to have no parking spaces, due to their size. This is also the case for the testing dataset, which mostly consists of small houses, but also has large houses, which, logically, should have parking spaces. So, based on this statistical summary, we can conclude that the parking spaces column most-likely contains missing values. Now, we need to decide how to deal with it.
#
# We can deal with missing data in the following ways: remove it, impute it, or interpolate it. Whichever method we pick, it does not make sense to apply this to all of the observations with the value of zero in the parking spaces column. If we choose to remove all of those values, we would lose a large chunk of the training dataset, which is something we cannot afford. If we choose to impute all of the values, we would get rid of the missing data, but we would invalidate a lot of observations with most-likely accurate values, which could greatly affect the accuracy of our model. Finally, if we chose to interpolate all of the observations, we could not only invalidate certain records, but we would also need there to be a solid relationship between the 'parking spaces' variable and other variables in order to accurately interpolate the values. As such, we need to apply one of the above methods to only certain observations in order to maintain a high degree of accuracy in our dataset.
#
# We still need to determine which observations we will apply the method to, though. For this, I am going to be using the numeric outlier technique. Although this is an outlier detection technique, I think it could be used appropriately here to identify observations, which are the likeliest to contain missing values in the 'parking spaces' column. I am going to filter the training dataset to find only observations with no parking spaces. Then, I will look at the distribution of the 'area' and 'rooms' columns, since they are most logically connected to the 'parking spaces' variable. I will calculate the 'upper bound' for those variables using the formula $q_3 + IQR*1.5$; this value corresponds to the top whisker in a boxplot. Any observation which contains a value above the upper bound in the column, which was used to calculate the upper bound, will be deemed an outlier, meaning it will most-likely contain missing data.
#
# The only choice that we have to make now is whether we will use the 'area' or the 'rooms' column to calculate the upper bound and identify any possible outliers. To do this, let's take a look at the distribution of both the columns when 'parking spaces' is equal to zero using a boxplot.

# %%
no_parking_train = X_train[X_train["parking spaces"] == 0]
fig, axs = plt.subplots(1, 2)
area_boxplot = sns.boxplot(y="area", data=no_parking_train, ax=axs[0])
area_boxplot.set(ylim=(0, 850))
room_boxplot = sns.boxplot(y="rooms", data=no_parking_train, ax=axs[1])
plt.show()

# %% [markdown]
# Based on these boxplots, I think both of the columns are great in order to identify the observations which most-likely contain the missing values in the 'parking spaces' clumn. I will be using the 'area' column; however, the 'rooms' column is also a great option.

# %%
k = 1.5
q1 = no_parking_train["area"].quantile(0.25)
q3 = no_parking_train["area"].quantile(0.75)
iqr = q3 - q1
threshold = q3 + k*iqr
above_threshold_train = no_parking_train[no_parking_train["area"] > threshold]

# %%
len(above_threshold_train) / len(X_train) * 100
# Out:
# 2.209750964573834

# %% [markdown]
# As you can see, approximately 2.21% of our training dataset most-likely contains missing values in the "parking spaces" column. We should also check how many similar observations are present in the training dataset using the same threshold. The reason why I am using the same threshold is to avoid any kind of data leakage.

# %%
no_parking_test = X_test[X_test["parking spaces"] == 0]
above_threshold_test = no_parking_test[no_parking_test["area"] > threshold]

# %%
len(above_threshold_test) / len(X_test) * 100
# Out:
# 2.664796633941094

# %% [markdown]
# Similarly to the training dataset, there are approximately 2.7% observations with most-likely missing values in the "parking spaces" column. I don't think imputing makes sense in this case, because the 'area' distribution of the outliers is quite wide, as we saw in the boxplot, whcih means imputation can lead to incorrect data. We could trying to interpolate the column, but first we need to check how strong the relationship is between the 'parking spaces' column and other features, specifically 'rooms' and 'area'.

# %%
X_train[["area", "rooms", "parking spaces"]].corr()
# Out:
#                     area     rooms  parking spaces
# area            1.000000  0.177574        0.178443
# rooms           0.177574  1.000000        0.623027
# parking spaces  0.178443  0.623027        1.000000

# %% [markdown]
# The relationship between the 'area' and 'parking spaces' columns is quite weak, so we cannot use the 'area' column for interpolation. The relationship between the 'rooms' and 'parking spaces' columns is moderately strong, but I don't think a single column is enough to guarantee accurate interpolation. As such, I think it is best to simply remove the observations we detected above, since we can afford to lose just over 2% for both the training and testing datasets.

# %%
X_train.drop(above_threshold_train.index, inplace=True)
X_test.drop(above_threshold_test.index, inplace=True)

# %%
y_train.drop(above_threshold_train.index, inplace=True)
y_test.drop(above_threshold_test.index, inplace=True)

# %% [markdown]
# Finally, let's check our target column for any missing data. Similarly to the previous analysis, we will look for non-positive values, since they make no sense in the 'rent amount' variable.

# %%
y_train[y_train["rent amount (R$)"] < 1]
# Out:
# Empty DataFrame
# Columns: [rent amount (R$)]
# Index: []

# %%
y_test[y_test["rent amount (R$)"] < 1]
# Out:
# Empty DataFrame
# Columns: [rent amount (R$)]
# Index: []

# %% [markdown]
# As you can see, there are no non-positive values in the target variable in both the training and testing dataset, and so we can confirm that the target variable contains no missing values.
#
# Now that we are done working with missing values, let's move on to encoding all of the categorical variables in our dataset.

# %% [markdown]
# #### Categorically Encoding Data
# We will now move on to encoding the categorical variables in the dataset in order to prepare it for more data preprocessing. Let's begin by looking at the categorical columns we will have to deal with and deciding how to encode.

# %%
houses.select_dtypes(exclude=np.number).columns.tolist()
# Out:
# ['city', 'animal', 'furniture']

# %% [markdown]
# We will start by encoding the 'animal' and 'furniture' columns. As we saw previously, those columns only have two unique values. For the 'animal' variable, either the house/apartment accepts animals or it does not. Similarly, the 'furniture' column indicates only if the column is furnished or not. As such, we will make the two columns binary. This means that if the apartment accepts animals or is furnished, it will contain a 1 in its respective column, and 0 otherwise.

# %%
X_train["animal"] = X_train["animal"] == "acept"
X_train["animal"] = X_train["animal"].astype(int)
X_test["animal"] = X_test["animal"] == "acept"
X_test["animal"] = X_test["animal"].astype(int)

# %%
X_train["furniture"] = X_train["furniture"] == "furnished"
X_train["furniture"] = X_train["furniture"].astype(int)
X_test["furniture"] = X_test["furniture"] == "furnished"
X_test["furniture"] = X_test["furniture"].astype(int)

# %% [markdown]
# Now, let's move on to the 'city' column. As we saw previously, the column contains 5 different Brazilian cities. Since there are only 5 of them and the data is not ordinal, we should encode the column using the One-Hot Encoding method. We should also make sure that all 5 cities are in both the training and testing datasets.

# %%
len(X_train["city"].unique()) == len(X_test["city"].unique())
# Out:
# True

# %% [markdown]
# The two unique lists are equal, so we don't need to focus on handling unknown values.

# %%
oh_encoder = OneHotEncoder(sparse=False)
ohe_city_train = pd.DataFrame(oh_encoder.fit_transform(X_train[["city"]]))
ohe_city_train.index = X_train.index
ohe_city_test = pd.DataFrame(oh_encoder.transform(X_test[["city"]]))
ohe_city_test.index = X_test.index

# %%
X_train.drop("city", inplace=True, axis=1)
X_test.drop("city", inplace=True, axis=1)

# %%
X_train = X_train.merge(ohe_city_train, right_index=True, left_index=True)
X_test = X_test.merge(ohe_city_test, right_index=True, left_index=True)

# %% [markdown]
# #### Working with Outliers
# We will now move on to identifying outliers in our dataset. To do so, we are going to use Mahalanobis Distance. Mahalanobis Distance is a measure of distance between a point and its distribution. It uses the inverse of a covariance matrix of variables in the combination with the data's center to find the distance, which means that it detects outliers based on the pattern of data points. If you would like to find out more about Mahalanobis Distance or other outlier detection techniques, please check out my [Outlier Detection Techniques Notebook](https://www.kaggle.com/karimzakir02/outlier-detection-techniques), which talks about Mahalanobis Distance and three other outlier detection methods.
#
# Mahalanobis Distance is great for this dataset, since our data is multivariate. Additionally, Mahalanobis Distance will adapt to our data's "wide" distribution, making it a better alternative to other techniques like Euclidean Distance, which does not consider the distribution of the data.
#
# As a cut-off value, I am going to be using the 0.99 Chi-Square distribution cut-off, since I am interested in finding the most extreme points in the dataset. To avoid data leakage, we are going to find this cut-off point only for the training dataset and then apply the same value for the testing dataset. I am going to measure the Mahalanobis Distance for both of the datasets.
#
# After identifying outliers, we will take a closer look at them and decide whether to keep them within the dataset or to remove them entirely, depending on the observation itself.

# %%
training_dataset = X_train.merge(y_train, left_index=True, right_index=True)
inv_cov = np.linalg.matrix_power(training_dataset.cov(), -1)
mean = np.mean(training_dataset)
training_dataset["mahalanobis_distance"] = np.NaN
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3478d734f204> in <module>
# ----> 1 training_dataset = X_train.merge(y_train, left_index=True, right_index=True)
#       2 inv_cov = np.linalg.matrix_power(training_dataset.cov(), -1)
#       3 mean = np.mean(training_dataset)
#       4 training_dataset["mahalanobis_distance"] = np.NaN
#
# NameError: name 'X_train' is not defined

# %%
for index, row in training_dataset.iterrows():
    values = row[0:13]
    training_dataset.loc[index, "mahalanobis_distance"] = mahalanobis(values, mean, inv_cov)**2

# %%
mahalanobis_threshold = chi2.ppf(0.99, training_dataset.shape[1] - 1)
mahalanobis_outliers = training_dataset[training_dataset["mahalanobis_distance"] > mahalanobis_threshold]
len(mahalanobis_outliers)
# Out:
# 395

# %%
mahalanobis_threshold
# Out:
# 27.68824961045705

# %%
mahalanobis_outliers.sort_values("mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 2397  46335      4         8               5     11       1          1  1.0
# 2562     80      3         2               2    301       1          0  1.0
# 5915  24606      5         4               4     12       1          0  0.0
# 2182    700      4         7               8      0       1          0  0.0
# 2619     80      2         1               1      1       1          0  0.0
# ...     ...    ...       ...             ...    ...     ...        ...  ...
# 176     500      4         5               8      0       1          0  0.0
# 4249     55      1         1               1      0       1          1  0.0
# 1781    300      4         3               2      5       0          1  0.0
# 4987     90      2         1               1      2       1          1  0.0
# 4969     70      2         1               1      2       1          1  0.0
#
# ...

# %% [markdown]
# As you can see, there are 355 outliers in our training dataset. Based on the sorted dataframe, the mahalanobis distance's range is quiet wide. It is ill-advised to remove outliers right away without checking for their valdiity. Our aim is to remove only those outliers, which are most-likely data-entry errors or are outright unrealistic relative to other data. As such, we will look at the outliers in chunks, by slowly decreasing the Mahalanobis Distance filter.

# %%
training_dataset[training_dataset["mahalanobis_distance"] >= 100]
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 2562     80      3         2               2    301       1          0  1.0
# 5915  24606      5         4               4     12       1          0  0.0
# 2182    700      4         7               8      0       1          0  0.0
# 2397  46335      4         8               5     11       1          1  1.0
#
#         1    2    3    4  rent amount (R$)  mahalanobis_distance
# 2562  0.0  0.0  0.0  0.0              2600           2337.650049
# 5915  0.0  0.0  0.0  1.0              8100           1817.956739
# 2182  0.0  0.0  0.0  1.0             45000            225.659480
# 2397  0.0  0.0  0.0  0.0              8500           6447.581729

# %% [markdown]
# For these observations, it is quite clear that they should be removed, because they contain data-entry errors or unrealistic values. For observation 2562, the floor value is unrealistic; for observations 5915 and 2397, the area values are all unrealistic; for observation 2182, the rent amount is unrealistic. This is debatable though, without any data to compare with, so we will find apartments with similar area and check for their rent amount values.

# %%
training_dataset[(training_dataset["area"] > 650) & (training_dataset["area"] < 750)].drop(2182).describe()
# Out:
#              area      rooms   bathroom  parking spaces      floor  animal  \
# count   29.000000  29.000000  29.000000       29.000000  29.000000    29.0
# mean   692.689655   5.000000   5.758621        5.586207   2.448276     1.0
# std     20.920092   1.224745   1.430663        1.880677   5.609852     0.0
# min    651.000000   3.000000   3.000000        2.000000   0.000000     1.0
# 25%    680.000000   4.000000   5.000000        4.000000   0.000000     1.0
# 50%    700.000000   5.000000   6.000000        5.000000   0.000000     1.0
# 75%    700.000000   6.000000   7.000000        8.000000   0.000000     1.0
# max    744.000000   8.000000   8.000000        8.000000  17.000000     1.0
#
#        furniture          0          1          2          3          4  \
# count  29.000000  29.000000  29.000000  29.000000  29.000000  29.000000
# mean    0.275862   0.206897   0.068966   0.034483   0.034483   0.655172
# std     0.454859   0.412251   0.257881   0.185695   0.185695   0.483725
# ...

# %% [markdown]
# Without the observation 2182, we see that the mean for the rent amount column is less than 11000 BRL, which is much less than the value recorded for observation 2182. As such, we can conclude that it is most likely an unrealistic reflection of the housing market, and remove this observation from the dataset. I will continue to do similar analysis for other outliers in the dataset, but I won't show the code for that part, since that would take up too much space in the notebook.
#
# Let's continue by viewing more identified outliers.

# %%
to_remove = [2562, 5915, 2182, 2397]

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 100) & (training_dataset["mahalanobis_distance"] >= 60)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 2619     80      2         1               1      1       1          0  0.0
# 5445    190      1         2              10      0       1          0  0.0
# 6947    486      8         4               6      0       1          0  0.0
# 4813   1600      4         5              12      0       1          0  0.0
# 1810    450      6         2               8      0       1          0  0.0
# 1639    400     10         5               8      0       1          0  0.0
# 1946    600      7         6               1     12       0          1  0.0
# 10619   360      1         1               8      0       1          0  1.0
#
#          1    2    3    4  rent amount (R$)  mahalanobis_distance
# 2619   0.0  0.0  0.0  1.0             24000             93.525367
# 5445   0.0  0.0  0.0  1.0              3900             87.582935
# 6947   0.0  0.0  0.0  1.0             25000             84.933548
# ...

# %% [markdown]
# Similarly to the previous observations, these one have also quite unrealistic values, which are most-likely data-entry errors. I will quickly breakdown each observation and state why I am removing it.
#
# - 1946 - the amount of parking spaces is too low, given the relatively high rooms value
# - 5445, 10619 - parking spaces value is too high for given area; rooms value is too low for given area
# - 2619, 6947 - the rent amount is too high for the given area values
# - 4813, 1810 - area and parking spaces value is too high for given rent amount value
# - 1639 - the values of the observation seem too high for the given area and rent amount

# %%
to_remove.extend([1946, 5445, 10619, 2619, 6947, 4813, 1810, 1639])

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 60) & (training_dataset["mahalanobis_distance"] >= 50)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 6454    387      7         5               3      0       1          1  0.0
# 4829    250      2         4               8      0       1          0  0.0
# 9464    100      3         2               8      0       1          0  0.0
# 9565    400      9         4               4      0       1          0  0.0
# 9989    295      7         6               4      0       0          1  0.0
# 9788    188      2         3               8      0       1          0  0.0
# 10125   230      2         1               8      0       1          0  0.0
# 5178    400     10         9               8      0       1          0  0.0
# 9857   1000      4         2               8      0       1          0  0.0
# 1334    650      5         4               8      0       1          1  0.0
# 5525    900      3         4               8      0       1          0  0.0
# ...

# %% [markdown]
# - 5178: Kept - the observation seems realistic after examining observations with similar areas
# - 752: Kept - the observation seems realistic after examining observations with similar areas
# - 1946: Removed - the amount of parking spaces is unrealistic, given the relatively high rooms value
# - 10125: Removed - the amount of parking spaces is unrealistic, given the relatively small rooms values
# - 9857: Removed - the values in the observation do not fit with each other overall
# - 2055: Kept - the observation seems realistic after examining observations with similar areas
# - 5525: Removed - the amount of parking spaces is unrealistic, given the relatively small rooms values
# - 3066: Removed - the amount of rooms does not fit well with other values, like bathroom/parking spaces values
# - 9012: Removed - the amount of rooms seems unrealistic, given the area and the price; the parking spaces value is also unrealistic

# %%
to_remove.extend([1946, 10125, 9857, 5525, 3066, 9012])

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 50) & (training_dataset["mahalanobis_distance"] >= 40)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 4829    250      2         4               8      0       1          0  0.0
# 5998    330      4         2               8      0       0          0  0.0
# 9442    250      2         2               8      0       1          1  0.0
# 9479    250      4         2               8      0       1          0  0.0
# 1130    360      4         9               8      0       1          0  0.0
# 9788    188      2         3               8      0       1          0  0.0
# 8380     43      2         7               2     11       1          0  0.0
# 9464    100      3         2               8      0       1          0  0.0
# 1780    350      2         4               8      0       0          0  0.0
# 1253    315      3         5               2     14       0          0  0.0
# 20      100      7         4               0      0       1          0  0.0
# ...

# %% [markdown]
# - 4829, 5998, 9442, 9479, 1130, 9788, 9464, 2845, 3853, 6384, 6851, 801, 9822, 10376 - the amount of parking spaces is too high for the given area/rooms values
# - 4088, 1571, 1780 - the rent amount is realistically too low for the given area/rooms values
# - 6423 - the rent amount is realistically too high for the given area/rooms values
# - 2398, 3853 - the rooms value is realistically too low for the given area value, and parking spaces value is too high
# - 4634, 2867, 20 - the rooms value is too high for the given area values
# - 8380 - the bathroom value is too high for the given area and rooms values
# - 6014 - the parking spaces value is too low for the given area/rooms values

# %%
to_remove.extend([4829, 5998, 9442, 9479, 1130, 9788, 9464, 2845, 3853, 6384, 6851, 801, 9822, 10376, 4088, 1571, 1780, 6423, 2398, 3853, 4634, 2867, 20, 8380, 6014])

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 40) & (training_dataset["mahalanobis_distance"] >= 35)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 4497    250      3         2               8      0       1          0  0.0
# 4541    400      6         6               8     15       1          1  0.0
# 5293    850      5         7               8      1       0          0  0.0
# 10256   460      5         8               5      0       0          0  1.0
# 5528    305      4         5               5     29       1          0  1.0
# 3348    355      3         4               8      8       1          0  1.0
# 1764    108      3         1               1      3       0          1  0.0
# 9995    386      3         4               8      0       1          0  1.0
# 510     417      3         5               8      0       1          0  1.0
# 6954    700      3         3               8      0       1          1  0.0
# 1020    845      5         9               6      0       1          1  0.0
# ...

# %% [markdown]
# - 4497, 3348, 9995, 510, 6954, 9568, 8943, 1838, 8334  - the amount of parking spaces is too high for the given rooms values
# - 1764, 4027, 317, 2106, 9856 - the rent amount is realistically too high for the given area and rooms values
# - 5293, 7597, 7226, 1138, 8399 - the rent amount is realistically too low for the given area value
#
# All other observations were deemed realistic enough in order to be kept within the training dataset

# %%
to_remove.extend([4497, 3348, 9995, 510, 6954, 1764, 5293, 4027, 317, 9568, 8943, 1838, 8334, 2106, 7597, 7226, 1138, 9856, 8399])

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 35) & (training_dataset["mahalanobis_distance"] >= 31)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 831     340      4         3               8      0       1          0  0.0
# 10380   800      4         7               4      0       1          0  0.0
# 9775    100      3         2               0      0       0          0  1.0
# 816     367      3         4               4      8       0          0  0.0
# 9749    420      4         3               8      0       1          0  1.0
# 2275    300      3         3               8      0       1          0  0.0
# 2627    305      4         5               5     26       1          0  1.0
# 911      75      3         1               1      1       0          0  0.0
# 9363    500      4         6               4      0       0          0  1.0
# 7433    457      6         6               2      0       1          1  0.0
# 10108   300      4         3               8      0       1          0  0.0
# ...

# %% [markdown]
# - 2275, 6482, 3485, 863, 4594, 1697, 1568, 10558, 1159 - the amount of parking spaces is realistically too high for the given rooms values
# - 9775, 10416, 10082, 680, 8067, 8587, 8080, 9663, 911, 6506, 816, 2627 - the rent amount is too high for the given area/rooms values
# - 6996, 2642, 5685, 6219, 7675 - the rent amount is too low for the given area values

# %%
to_remove.extend([2275, 6482, 3485, 863, 4594, 1697, 1568, 10558, 1159, 9775, 10416, 10082, 6996, 2642, 680, 8067, 8587, 8080, 9663, 911, 5685, 6219, 7675, 6506, 816, 2627])

# %%
training_dataset[(training_dataset["mahalanobis_distance"] < 31) & (training_dataset["mahalanobis_distance"] >= mahalanobis_threshold)].sort_values(by="mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 10530   230      3         4               4     17       1          1  1.0
# 10410   500      4         4               8     12       1          1  0.0
# 10392   480      5         4               7      0       1          0  0.0
# 6202    650      3         7               2      0       1          0  0.0
# 607     311      3         4               3     20       0          0  1.0
# 707     230      4         4               8      0       1          0  0.0
# 770     250      4         2               3      2       0          1  0.0
# 5288    500      4         8               4      0       1          1  0.0
# 8727    330      5         7               5     10       1          0  1.0
# 753     600      5         6               8      0       1          1  1.0
# 5002    570      3         6               2     11       1          0  0.0
# ...

# %% [markdown]
# - 676, 9948 - the amount of parking spaces is realistically too high for the given rooms values
# - 6673, 1719, 3092, 8327, 2859, 6185, 6823, 4719, 4170, 9833, 1491, 770, 10530, 5611, 1743, 4681, 5288, 607 - the rent amount is too high for the given area/rooms values
# - 595, 2624, 8678, 4025, 5763, 10392, 7192, 1877 - the rent amount is too low for the given area values
# - 6202 - the amount of rooms is too low for the given area value

# %%
to_remove.extend([676, 6673, 595, 1719, 3092, 8327, 2859, 6185, 2624, 6823, 4719, 4170, 9833, 1491, 770, 8678, 4025, 9948, 5763, 10530, 10392, 5611, 7192, 1743, 1877, 4681, 5288, 607, 6202])

# %%
X_train.drop(to_remove, inplace=True)
y_train.drop(to_remove, inplace=True)

# %%
testing_dataset = X_test.merge(y_test, left_index=True, right_index=True)
testing_dataset["mahalanobis_distance"] = np.NaN

# %%
for index, row in testing_dataset.iterrows():
    values = row[0:13]
    testing_dataset.loc[index, "mahalanobis_distance"] = mahalanobis(values, mean, inv_cov)**2

# %%
len(testing_dataset[testing_dataset["mahalanobis_distance"] > mahalanobis_threshold])
# Out:
# 53

# %%
testing_dataset[testing_dataset["mahalanobis_distance"] > mahalanobis_threshold].sort_values("mahalanobis_distance", ascending=False)
# Out:
#        area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 7835    439     13         4               3      0       1          0  0.0
# 7748    350      3         3               3      0       1          0  0.0
# 9021    458      8        10               4      0       1          0  1.0
# 5694     64      2         2               2     51       1          0  0.0
# 7826     83      2         1               8      0       1          0  0.0
# 1528    250      4         1               8      0       1          0  1.0
# 5660    300      8         3               1      0       1          0  1.0
# 6101    465      7         7               2      0       1          1  1.0
# 1654    353      4         5               5     46       1          0  0.0
# 8312    332      3         2               8      0       0          0  1.0
# 3251    550      3         7               8      0       1          0  0.0
# ...

# %% [markdown]
# - 8874, 1676, 7826, 8312, 8966 - the amount of parking spaces is realistically too high for the given rooms values
# - 10472 - the amount of rooms is too low for the given area value
# - 6504, 2315, 6777, 1976, 4993, 2338, 2576, 7748, 7835, 6101, 4224 - the rent amount is too high for the given area/rooms values
# - 4517, 6753, 628, 2998, 8362, 7742, 8628, 10587, 1426, 5660, 1528 - the rent amount is too low for the given area values

# %%
to_remove_test = [8874, 1676, 10472, 7826, 8312, 6504, 4517, 6753, 628, 2315, 6777, 2998, 1976, 8362, 4993, 7742, 2338, 8628, 2576, 8966, 10587, 1426, 5660, 7748, 1528, 7835, 6101, 4224]

# %%
X_test.drop(to_remove_test, inplace=True)
y_test.drop(to_remove_test, inplace=True)

# %% [markdown]
# #### Feature Selection

# %% [markdown]
# We will now select the best features for our model by seeing whether the potential features have any effect on the target variable

# %%
training_dataset = X_train.merge(y_train, left_index=True, right_index=True)

# %% [markdown]
# **The 'area' column:**
#
# The 'area' column indicates how big an apartment or a house is. It is unspecificed whether the measurements are in square feet or square meters, but it is possible to deduce that they are in square meters based on the data's scale. Based on basic knowledge, the area variable should have a positive correlation with the rent amount column, since a bigger apartment would have a higher price. Still, though, we should look closer at the column and ensure that this is also the case with our training dataset.

# %%
sns.scatterplot(data=training_dataset, x="area", y="rent amount (R$)")
# Out:
# <AxesSubplot:xlabel='area', ylabel='rent amount (R$)'>

# %% [markdown]
# Based on this scatterplot, we can see that there' a moderately strong positive correlation. One point that does stand out within this plot is the datapoint around the 2000 area mark. As we can see, it only has 5000 BRL in its rent amount column, making it an outlier, and most likely a data-entry. Let's take a look at it in more detail and decide whether it should be removed.

# %%
training_dataset[training_dataset["area"] >= 2000]
# Out:
#       area  rooms  bathroom  parking spaces  floor  animal  furniture    0  \
# 8790  2000      3         3               2      2       1          1  1.0
#
#         1    2    3    4  rent amount (R$)
# 8790  0.0  0.0  0.0  0.0              5000

# %% [markdown]
# Based on these values, we can conclude that this value is most likely a data-entry error, since it extremely unlikely that an apartment/house so large would be offered for only 5000 BRL. Let's remove this observation.

# %%
training_dataset.drop(8790, inplace=True)
X_train.drop(8790, inplace=True)
y_train.drop(8790, inplace=True)

# %%
sns.scatterplot(data=training_dataset, x="area", y="rent amount (R$)")
# Out:
# <AxesSubplot:xlabel='area', ylabel='rent amount (R$)'>

# %%
training_dataset[["area", "rent amount (R$)"]].corr()
# Out:
#                       area  rent amount (R$)
# area              1.000000          0.694103
# rent amount (R$)  0.694103          1.000000

# %% [markdown]
# Based on both the scatterplot and the numerical correlation, we can conclude that area affects rent amount in our training dataset as well and should definitely be a feature in our model.

# %% [markdown]
# **The 'rooms' column:**
#
# The 'rooms' column indicates how many rooms the apartment has. It is quite debatable whether this variable should be a feature. On the one hand, more rooms can indicate more bedrooms and more space, which can possibly drive up the price of the apartment. On the other hand, more rooms simply indicates more area within the apartment, meaning that the 'rooms' variable could just be a proxy for the 'area' variable, which is not worth including in our model.
#
# As we saw previously during outlier analysis, apartments/houses with similar areas can have different amount of rooms, suggesting that the 'rooms' variable does not always act like a proxy variable. So, the real question now is whether the amount of rooms for apartments/houses with similar areas affects the target variable. We will answer this question by looking at apartments/houses with similar 'area' values, but different 'rooms' values and seeing whether the price is affected or not.
#
# Specifically, we will take a segment of the training dataset

# %%
# Consider plotting at different axis, so that you can properly see the range of the area differences
# This should also be done for other analysis
counter = 100
counters = []
rent_diffs = []
area_diffs = []
while counter < 400:
    counters.append(counter)
    training_segment = training_dataset[(training_dataset["area"] < counter+10) & (training_dataset["area"] >= counter)]
    rooms_2 = training_segment[training_segment["rooms"] == 2]
    rooms_4 = training_segment[training_segment["rooms"] == 4]
    rooms_2_area = rooms_2[["area", "rent amount (R$)"]].mean().loc["area"]
    rooms_4_area = rooms_4[["area", "rent amount (R$)"]].mean().loc["area"]
    area_diffs.append(rooms_2_area - rooms_4_area)
    rooms_2_rent = rooms_2[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    rooms_4_rent = rooms_4[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    rent_diffs.append(rooms_2_rent - rooms_4_rent)
    counter += 10

# %%
to_plot_rent = pd.DataFrame({"counters": counters, "diffs": rent_diffs}, columns=["counters", "diffs"])
to_plot_rent["label"] = "rent differences"
to_plot_area = pd.DataFrame({"counters": counters, "diffs": area_diffs}, columns=["counters", "diffs"])
to_plot_area["label"] = "area differences"
to_plot = pd.concat([to_plot_rent, to_plot_area], ignore_index=True)

# %%
sns.lineplot(x="counters", y="diffs", hue="label", data=to_plot)
# Out:
# <AxesSubplot:xlabel='counters', ylabel='diffs'>

# %% [markdown]
# As you can see, at certain points, despite having extremely similar average areas, the price changes are drastic and can go up to 4000 BRL. This suggests that rooms is a worthy feature to have, since it does not just act as a proxy to the 'area' column and does not perfectly correlate with that column.

# %% [markdown]
# **The 'bathroom' column:**
#
# The 'bathroom' column indicates the amount of bathroom in an apartment/house. Similarly to the 'rooms' column, it is unclear whether this column affects the target variable individually or whether it acts as a proxy variable to the 'area' and the 'rooms' columns. As such, we will conduct a similar experiment with this column as we did with the "rooms column"

# %%
counter = 100
counters = []
rent_diffs = []
area_diffs = []
room_diffs = []
while counter < 250:
    counters.append(counter)
    training_segment = training_dataset[(training_dataset["area"] < counter+10) & (training_dataset["area"] >= counter)]
    bathroom_1 = training_segment[training_segment["bathroom"] == 1]
    bathroom_3 = training_segment[training_segment["bathroom"] == 3]
    bathroom_1_area = bathroom_1[["area", "rent amount (R$)"]].mean().loc["area"]
    bathroom_3_area = bathroom_3[["area", "rent amount (R$)"]].mean().loc["area"]
    area_diffs.append(bathroom_1_area - bathroom_3_area)
    bathroom_1_rooms = bathroom_1[["area", "rent amount (R$)", "rooms"]].mean().loc["rooms"]
    bathroom_3_rooms = bathroom_3[["area", "rent amount (R$)", "rooms"]].mean().loc["rooms"]
    room_diffs.append(bathroom_1_rooms - bathroom_3_rooms)
    bathroom_1_rent = bathroom_1[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    bathroom_3_rent = bathroom_3[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    rent_diffs.append(bathroom_1_rent - bathroom_3_rent)
    counter += 10

# %%
to_plot_rent = pd.DataFrame({"counters": counters, "diffs": rent_diffs}, columns=["counters", "diffs"])
to_plot_rent["label"] = "rent differences"
to_plot_area = pd.DataFrame({"counters": counters, "diffs": area_diffs}, columns=["counters", "diffs"])
to_plot_area["label"] = "area differences"
to_plot_rooms = pd.DataFrame({"counters": counters, "diffs": room_diffs}, columns=["counters", "diffs"])
to_plot_rooms["label"] = "room differences"
to_plot = pd.concat([to_plot_rent, to_plot_area, to_plot_rooms], ignore_index=True)

# %%
sns.lineplot(x="counters", y="diffs", hue="label", data=to_plot)
# Out:
# <AxesSubplot:xlabel='counters', ylabel='diffs'>

# %% [markdown]
# Similarly to the 'rooms' column, the 'bathroom' column seems to have a real effect on the price, because even when the area and the amount of rooms is simialar, we can see a vast difference in the rent amount average. As such, we will keep this column as part of our model.

# %% [markdown]
# **The 'parking spaces' column**
#
# The 'parking spaces' column indicates the amount of parking spaces that the potential tenant will have available to them. Although it may seem that the 'parking spaces' column is simply indicative of the 'rooms' variable and has no real effect on the target variable, it is definitely to argue the opposite. More parking spaces suggest that there's more space for cars, suggesting that higher-class households will be interested in such apartments; this kind of demographic will push the price up, especially if the landlords are aware of this demographic. Let's take a look at the correlation between parking spaces and the rent amount

# %%
counter = 100
counters = []
rent_diffs = []
area_diffs = []
room_diffs = []
while counter < 300:
    counters.append(counter)
    training_segment = training_dataset[(training_dataset["area"] < counter+10) & (training_dataset["area"] >= counter)]
    bathroom_1 = training_segment[training_segment["parking spaces"] == 2]
    bathroom_3 = training_segment[training_segment["parking spaces"] == 4]
    bathroom_1_area = bathroom_1[["area", "rent amount (R$)"]].mean().loc["area"]
    bathroom_3_area = bathroom_3[["area", "rent amount (R$)"]].mean().loc["area"]
    area_diffs.append(bathroom_1_area - bathroom_3_area)
    bathroom_1_rooms = bathroom_1[["area", "rent amount (R$)", "rooms"]].mean().loc["rooms"]
    bathroom_3_rooms = bathroom_3[["area", "rent amount (R$)", "rooms"]].mean().loc["rooms"]
    room_diffs.append(bathroom_1_rooms - bathroom_3_rooms)
    bathroom_1_rent = bathroom_1[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    bathroom_3_rent = bathroom_3[["area", "rent amount (R$)"]].mean().loc["rent amount (R$)"]
    rent_diffs.append(bathroom_1_rent - bathroom_3_rent)
    counter += 10

# %%
to_plot_rent = pd.DataFrame({"counters": counters, "diffs": rent_diffs}, columns=["counters", "diffs"])
to_plot_rent["label"] = "rent differences"
to_plot_area = pd.DataFrame({"counters": counters, "diffs": area_diffs}, columns=["counters", "diffs"])
to_plot_area["label"] = "area differences"
to_plot_rooms = pd.DataFrame({"counters": counters, "diffs": room_diffs}, columns=["counters", "diffs"])
to_plot_rooms["label"] = "room differences"
to_plot = pd.concat([to_plot_rent, to_plot_area, to_plot_rooms], ignore_index=True)

# %%
sns.lineplot(x="counters", y="diffs", hue="label", data=to_plot)
# Out:
# <AxesSubplot:xlabel='counters', ylabel='diffs'>

# %% [markdown]
# The 'parking spaces' column does affect the area, even when the amount of rooms and area stays relatively consistent throughout. As such, we should keep this feature in our model

# %% [markdown]
# **The 'floor' column:**
#
# The floor column indicates on which floor the apartment is. As mentioned previously, if the observation is on the 0th floor, it is possible that this particular observation is a house or an apartment on the ground floor. Unlike our previous columns, this column is unlikely to have any connection with other potential features. As such, we only need to check whether this column has a relationship with the target variable.

# %%
training_dataset[["floor", "rent amount (R$)"]].corr()
# Out:
#                      floor  rent amount (R$)
# floor             1.000000          0.105431
# rent amount (R$)  0.105431          1.000000

# %%
training_dataset[training_dataset["floor"] == 0][["area", "rent amount (R$)"]].mean()
# Out:
# area                 218.671356
# rent amount (R$)    4700.600450
# dtype: float64

# %%
training_dataset[training_dataset["floor"] >= 0][["area", "rent amount (R$)"]].mean()
# Out:
# area                 134.747121
# rent amount (R$)    3769.990059
# dtype: float64

# %% [markdown]
# **The 'animal' column**:
#
# The 'animal' column indicates whether the potential tenant can bring an animal into the house/apartment. It is not immediately clear whether this column will have a strong effect on the rent column, because not everyone owns pets or plans to in the future. As such, let's take a close look at the data to determine whether this column needs to be a feature in our model.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,4))
sns.barplot(data=training_dataset[["animal", "rent amount (R$)"]].groupby("animal").mean().reset_index(), y="rent amount (R$)", x="animal", ax=axs[0])
axs[0].set_title("Average rent for apartments which allow/disallow animals")
sns.countplot(data=training_dataset, x="animal", ax=axs[1])
axs[1].set_title("No. animal-friendly/unfriendly apartments in the dataset")
plt.show()

# %%
training_dataset[["area", "rooms", "rent amount (R$)", "animal"]].groupby("animal").mean()
# Out:
#               area     rooms  rent amount (R$)
# animal
# 0       103.484979  2.077790       3298.690987
# 1       143.873610  2.568677       3907.578387

# %% [markdown]
# The price difference is confirmed by both the plot and the table above; however, there's also a large difference in the mean 'area' measurements for the two categories, which could be the reason the prices are so different. As such, we need a different way of investigating whether the column truly affects the target variable or not.

# %%
animal_group = training_dataset[["area", "rooms", "rent amount (R$)", "animal"]].groupby("animal").get_group(1)
animal_group.sort_values("area", ascending=False, inplace=True)
area_mean = animal_group["area"].mean()
while area_mean > 105:
    animal_group = animal_group.iloc[1:]
    area_mean = animal_group["area"].mean()

# %%
animal_group["area"].mean()
# Out:
# 104.99516735278324

# %%
animal_group["rooms"].mean()
# Out:
# 2.3552890638983355

# %%
animal_group["rent amount (R$)"].mean()
# Out:
# 3233.693037408269

# %% [markdown]
# As you can see, the difference is quite small, suggesting that the animal column is simply not influential on the target variable and should not be included in our model. To ensure that this difference is not statistically significant, we should conduct a statistical experiment.

# %%
mean_animal = animal_group["rent amount (R$)"].mean()
no_animal_mean = 3298.690987
animal_test_statistic = mean_animal - no_animal_mean

# %%
no_animal_group = training_dataset[["area", "rooms", "rent amount (R$)", "animal"]].groupby("animal").get_group(0)
total_animal = pd.concat([animal_group, no_animal_group])

# %%
# Make sure that this is consistently calculated in the right order
np.random.seed(22)
sim_data = []
repetitions = 1000
for i in range(repetitions):
    animal_copy = total_animal.copy()
    animal_copy["shuffled_labels"] = pd.DataFrame(animal_copy["animal"].values, index=np.random.permutation(animal_copy.index))
    means = animal_copy.groupby("shuffled_labels").mean()["rent amount (R$)"].values.tolist()
    diff = means[0] - means[1]
    sim_data.append(diff)

# %%
sns.histplot(x=sim_data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
total = 0
for sim in sim_data:
    if sim > abs(animal_test_statistic) or sim < animal_test_statistic:
        total += 1
total / 1000 * 100
# Out:
# 35.099999999999994

# %% [markdown]
# The p-value is quite high, suggesting that our difference is not statistically significanct. In turn, this suggests that the 'animal' column should not be considered as a feature in our model.

# %% [markdown]
# **The 'furniture' column:**
#
# The furniture column indicates whether a partcular apartment is furnished or not. Logically, this column would have positively correlate with the target variable, since an unfurnished apartment would require a potential tenant to purchase their own furniture, driving their total cost up. As such, they would not be willing to pay as much for an unfurnished apartment. On the other hand, though, an unfurnished apartment means that the tenant can design it to their liking, which might be more attractive to certain people. So, let's check whether this feature has any influence on the target variable.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,4))
sns.barplot(data=training_dataset[["furniture", "rent amount (R$)"]].groupby("furniture").mean().reset_index(), y="rent amount (R$)", x="furniture", ax=axs[0])
axs[0].set_title("Average rent for furnished/unfurnished apartments")
sns.countplot(data=training_dataset, x="furniture", ax=axs[1])
axs[1].set_title("No. furnished/unfurnished apartments in the dataset")
plt.show()

# %% [markdown]
# As you can see, there's a significant difference in the average rent amount between unfurnished and furnished apartments. However, there's a possibility that the average price of unfurnished apartments is less in our training dataset is because the dataset is mostly made up of unfurnished apartments; this could imply that a majority of unfurnished apartments could possibly include a lot of low-cost housing, meaning that the average price could be affected by other factors and not whether the apartment is furnished or not. As such, we should check the average values for other features for the two categories in the furnished column.

# %%
training_dataset[["area", "rooms", "rent amount (R$)", "furniture"]].groupby("furniture").mean()
# Out:
#                  area     rooms  rent amount (R$)
# furniture
# 0          135.202150  2.505695       3444.198781
# 1          134.265741  2.309866       4777.370848

# %% [markdown]
# Despite my initial doubts, we can see that the average values for the two categories in the area and rooms column is incredibly similar, so it is highly unlikely that the price is affected by other features other than the furniture variable. There's still a possibility that our dataset is highly affected by chance and within the actual population, which is all of the houses/apartments available for rent in Brazil, there's no relationship between whether the apartment is furnished and the rent price of the house. As such, we need to conduct a statistical experiment.

# %%
furniture_means = furniture_X_train.groupby("furniture").mean()["rent amount (R$)"].values.tolist()
test_statistic = furniture_means[0] - furniture_means[1]
test_statistic
# Out:
# -1333.1720671102944

# %% [markdown]
# Let's now simulate test statistics, assuming that furniture does not affect the price of a house/apartment, and compare our test statistic to the estimated sampling distribution

# %%
np.random.seed(33)
sim_data = []
repetitions = 1000
for i in range(repetitions):
    furniture_copy = training_dataset.copy()
    furniture_copy["shuffled_labels"] = pd.DataFrame(furniture_copy["furniture"].values, index=np.random.permutation(furniture_copy.index))
    means = furniture_copy.groupby("shuffled_labels").mean()["rent amount (R$)"].values.tolist()
    diff = means[0] - means[1]
    sim_data.append(diff)

# %%
sns.histplot(x=sim_data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
total = 0
for sim in sim_data:
    if sim > abs(test_statistic) or sim < test_statistic:
        total += 1
total / 1000 * 100
# Out:
# 0.0

# %% [markdown]
# After assuming the null hypothesis during our analysis, we can see from the histogram that the furniture category would not have a great effect on the rent amount column. In fact, the p-value for this experiement is 0, so we can be quite confident that the furniture column does not just affect our training dataset but the entire population. This means that we can include the furniture as a feature in our model.

# %% [markdown]
# **The 'city' column:**
#
# The only column that is left is the 'city' column, which indicates where the apartment/house is located. As you remember earlier, we have one hot encoded the variable. It would make sense that apartments/houses in certain cities would be more expensive, as certain cities could have more attractive jobs or opportunities in general, causing the population to shift towards particular cities, driving up the real estate prices in those cities. Let's check whether this is true for the houses in our dataset.
#
# For ease of use, we are going to use the original city column.

# %%
training_dataset = training_dataset.merge(houses["city"], how="inner", left_index=True, right_index=True)

# %%
sns.countplot(data=training_dataset, x="city")
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(12,5))
mean_cities = training_dataset.groupby("city")[["rent amount (R$)", "area"]].mean()
sns.barplot(data=mean_cities, x=mean_cities.index, y="rent amount (R$)", ax=axs[0])
sns.barplot(data=mean_cities, x=mean_cities.index, y="area", ax=axs[1])
# Out:
# <AxesSubplot:xlabel='city', ylabel='area'>

# %% [markdown]
# After looking at these two bar plots, I think we can conclude that the 'city' variable strongly affects the target variable, without needing to account for the area differences. Take a closer look at the Belo Horizonte bars in the plots. Despite having the highest average area in the dataset, it's average rent amount is much lower when compared to Sao Paulo, whcih has similar average area. This is also the case for other cities, such as Campinas or Porto Alegre, which, despite having similar or greater average areas to Rio De Janeiro, still have lower average rent amount. As such, we will keep the encoded columns as features in our dataset.
#
# Let's now remove the 'floor' and 'animal' columns from our datasets and train and test our initial model.

# %% [markdown]
# ### Initial Model

# %%
X_train.drop(["animal", "floor"], axis=1, inplace=True)
X_test.drop(["animal", "floor"], axis=1, inplace=True)

# %%
init_model = XGBRegressor(n_estimators=10)
init_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
init_predictions = init_model.predict(X_test)
mean_absolute_error(init_predictions, y_test)
# Out:
# 1262.7539287444563

# %% [markdown]
# ### Custom Model

# %% [markdown]
# We are going to try both K-Means and the Mean-Shift algorithms and decide which one we should go with.

# %%
km_clf = KMeans(n_clusters=3)
km_clf.fit(X_train.iloc[:, 0:12])
# Out:
# KMeans(n_clusters=3)

# %%
X_train["km_labels"] = pd.DataFrame(km_clf.labels_, index=X_train.index)
y_train["km_labels"] = pd.DataFrame(km_clf.labels_, index=y_train.index)

# %%
test_labels = km_clf.predict(X_test)
X_test["km_labels"] = pd.DataFrame(test_labels, index=X_test.index)
y_test["km_labels"] = pd.DataFrame(test_labels, index=y_test.index)

# %%
km_groups_X_train = X_train.groupby("km_labels")
km_groups_y_train = y_train.groupby("km_labels")

# %%
km_groups_X_test = X_test.groupby("km_labels")
km_groups_y_test = y_test.groupby("km_labels")

# %%
km_error_measurements = {}
for name, group in km_groups_X_train:
    km_group_model = XGBRegressor(n_estimators=10)
    group_X_train = group.iloc[:, 0:12]
    group_y_train = km_groups_y_train.get_group(name)[["rent amount (R$)"]]
    km_group_model.fit(group_X_train, group_y_train)
    group_X_test = km_groups_X_test.get_group(name).iloc[:, 0:12]
    group_y_test = km_groups_y_test.get_group(name)[["rent amount (R$)"]]
    group_predictions = km_group_model.predict(group_X_test)
    km_error_measurements[name] = mean_absolute_error(group_predictions, group_y_test)

# %%
km_error_measurements
# Out:
# {0: 2399.2027262737197, 1: 847.6185748158592, 2: 3143.468939887153}

# %%
sns.countplot(data=X_test, x="km_labels")
# Out:
# <AxesSubplot:xlabel='km_labels', ylabel='count'>

# %%
ms_clf = MeanShift()
ms_clf.fit(X_train.iloc[:, 0:12])
# Out:
# MeanShift()

# %%
X_train["ms_labels"] = pd.DataFrame(ms_clf.labels_, index=X_train.index)
y_train["ms_labels"] = pd.DataFrame(ms_clf.labels_, index=y_train.index)

# %%
ms_groups_X_train = X_train.groupby("ms_labels")
ms_groups_y_train = y_train.groupby("ms_labels")

# %%
sns.countplot(data=X_train, x="ms_labels")
# Out:
# <AxesSubplot:xlabel='ms_labels', ylabel='count'>

# %%
print(f"There are {len(ms_groups_X_train.get_group(0))} in group 0")
print(f"There are {len(ms_groups_X_train.get_group(1))} in group 1")
print(f"There are {len(ms_groups_X_train.get_group(2))} in group 1")
print(f"There are {len(ms_groups_X_train.get_group(3))} in group 3")
print(f"There are {len(ms_groups_X_train.get_group(4))} in group 4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-05fdc030d418> in <module>
# ----> 1 print(f"There are {len(ms_groups_X_train.get_group(0))} in group 0")
#       2 print(f"There are {len(ms_groups_X_train.get_group(1))} in group 1")
#       3 print(f"There are {len(ms_groups_X_train.get_group(2))} in group 1")
#       4 print(f"There are {len(ms_groups_X_train.get_group(3))} in group 3")
#       5 print(f"There are {len(ms_groups_X_train.get_group(4))} in group 4")
#
# NameError: name 'ms_groups_X_train' is not defined

# %% [markdown]
# As you can see above, an overwhelming majority of observations is in group 0, while all other groups contain very little observations. In my opinion, it is not worth it to continue with the mean shift algorithm, because there are not enough observations in most of the classes in order to properly train the model. So, we will only stick with the k-means clustering algorithm

# %% [markdown]
# ### Looking at Accuracy in More Detail...

# %%
y_test["initial predictions"] = pd.DataFrame(init_predictions, index=y_test.index)
y_test["initial error"] = abs(y_test["rent amount (R$)"] - y_test["initial predictions"])

# %%
km_groups_y_test = y_test.groupby("km_labels")

# %%
y_test.groupby("km_labels").mean()
# Out:
#            rent amount (R$)  initial predictions  initial error
# km_labels
# 0               6538.205418          6479.800293    2362.864817
# 1               2599.900723          2558.185547     840.156695
# 2              10476.766667          9658.750977    2989.656923

# %%
846.394984 / 2602.001970 * 100
# Out:
# 32.52860657903345

# %%
2443.138294 / 6624.610245 * 100
# Out:
# 36.879728823955894

# %%
3539.218286 / 10444.926829 * 100
# Out:
# 33.884567541186364

# %% [markdown]
# #### Why hasn't our model performed well?

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Despite my initial ideas, we saw very similar performance in the simple model and the model which used a clustering algorithm along with the XGBoost algorithm. Does that mean that this experiment was useless though? Not exactly. Firstly, using the KMeans clustering algorithm, we saw that the model performs differently in terms of raw values for different clusters. Secondly, I am glad that I actually did this idea, even if the conclusion was unsatisfying. Finally, I got quite a bit of experience with data preprocessing and with using Mahalanobis Distance in 'real' analysis.
#
#
# I hope you also got something out of this notebook. If you have any comments or suggestions, feel free to comment under the Kaggle Notebook!
